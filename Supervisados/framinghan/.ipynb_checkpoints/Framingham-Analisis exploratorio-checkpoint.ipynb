# %% [markdown]
# # Analisis exploratorio.
# * En esta parte intentaremos ver informacion relevante del dataset para entender su comportamiento.

# %%
#Librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Arbol de decision
from sklearn.tree import DecisionTreeClassifier

#Visualizacion del arbol
from sklearn.tree import export_graphviz

#Para el bosque aleatorio.
from sklearn.ensemble import RandomForestClassifier

# %%
#Importacion del dataset
dataset = pd.read_csv("framinghamClean.csv")
dataset.drop(["Unnamed: 0"], axis=1, inplace=True)
dataset.head(3)
dataset.shape[0]
# Out:
# 4240

# %%
dataset["TenYearCHD"].value_counts()
# Out:
# 0    3596
# 1     644
# Name: TenYearCHD, dtype: int64

# %%
dataset.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4240.000000    4240.000000  4240.000000
# mean      0.429245    49.580189     1.979953       0.494104     9.012736
# std       0.495027     8.572942     1.007087       0.500024    11.881892
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4240.000000      4240.000000   4240.000000  4240.000000  4240.000000
# mean      0.029245         0.005896      0.310613     0.025708   236.703066
# std       0.168513         0.076569      0.462799     0.158280    44.327533
# ...

# %%
sns.histplot(x=dataset["male"], kde=True)
# Out:
# <AxesSubplot:xlabel='male', ylabel='Count'>

# %%
dataset[dataset["male"]==0].shape[0] #Numero de mujeres en el estudio
# Out:
# 2420

# %%
dataset[dataset["male"]==1].shape[0]
# Out:
# 1820

# %%
dataset[dataset["male"]==0].shape[0]/dataset["male"].shape[0]
# Out:
# 0.5707547169811321

# %%
dataset[dataset["male"]==1].shape[0]/dataset["male"].shape[0]
# Out:
# 0.42924528301886794

# %%
dataset[dataset["male"]==1].shape
# Out:
# (1820, 16)

# %%
sns.histplot(x = dataset["education"])
# Out:
# <AxesSubplot:xlabel='education', ylabel='Count'>

# %%
dataset["education"].value_counts()
# Out:
# 1.0    1720
# 2.0    1358
# 3.0     689
# 4.0     473
# Name: education, dtype: int64

# %%
sns.histplot(x="TenYearCHD",data=dataset)
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='Count'>

# %%
dataset["TenYearCHD"].value_counts()
# Out:
# 0    3596
# 1     644
# Name: TenYearCHD, dtype: int64

# %%
#Relacion edad, enfermedad.
sns.boxplot(x='TenYearCHD',y='age',data=dataset)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='age'>

# %%
#Sexo y enfermedad.
sns.boxplot(x='TenYearCHD',y='age',hue="male",data=dataset)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Cigarros y enfermedad
#Gente que no fuma.
dataset[(dataset["currentSmoker"]==0) & (dataset["TenYearCHD"]==1) & (dataset["prevalentHyp"]==1)]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 28       0   61        3.0              0         0.0     0.0
# 32       0   59        1.0              0         0.0     0.0
# 42       0   52        1.0              0         0.0     1.0
# 44       0   53        3.0              0         0.0     1.0
# 75       0   59        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4123     1   51        3.0              0         0.0     0.0
# 4125     0   64        1.0              0         0.0     0.0
# 4193     0   63        1.0              0         0.0     0.0
# 4223     1   56        4.0              0         0.0     1.0
# 4232     1   68        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 28                  0             1         0    272.0  182.0  121.0  32.80
# ...

# %%
dataset[(dataset["currentSmoker"]==1) & (dataset["TenYearCHD"]==1) & (dataset["prevalentHyp"]==0)]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 17       0   46        2.0              1        20.0     0.0
# 25       1   47        4.0              1        20.0     0.0
# 33       1   61        2.0              1         5.0     0.0
# 48       0   63        2.0              1        40.0     0.0
# 59       0   40        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4163     1   65        4.0              1         6.0     0.0
# 4171     1   41        2.0              1        43.0     0.0
# 4189     1   54        2.0              1        20.0     0.0
# 4192     1   45        1.0              1        20.0     0.0
# 4214     0   56        3.0              1         5.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 17                  0             0         0    291.0  112.0   78.0  23.38
# ...

# %%
#Sexo y enfermedad. 192 mujeres y 119 hombres
dataset[(dataset["currentSmoker"]==0) & (dataset["TenYearCHD"]==1) & (dataset["male"]==0)]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 6        0   63        1.0              0         0.0     0.0
# 28       0   61        3.0              0         0.0     0.0
# 32       0   59        1.0              0         0.0     0.0
# 42       0   52        1.0              0         0.0     1.0
# 44       0   53        3.0              0         0.0     1.0
# ...    ...  ...        ...            ...         ...     ...
# 4125     0   64        1.0              0         0.0     0.0
# 4188     0   44        3.0              0         0.0     0.0
# 4193     0   63        1.0              0         0.0     0.0
# 4199     0   61        1.0              0         0.0     0.0
# 4207     0   61        4.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 6                   0             0         0    205.0  138.0   71.0  33.11
# ...

# %% [markdown]
# ## Insights
# * De los pacientes analizados solo el ~15% desarrollo una enfermedad del corazon.
# * De ese aprox la mitad fuma y la otra no.
# * De ese aprox la mitad son mujeres y la otra hombres.
# * De ese aprox la mitad tiene hipertension y la otra no
